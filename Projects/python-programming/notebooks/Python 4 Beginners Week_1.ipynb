# %% [markdown]
# # 📅 Day 1: Introduction to Python, Printing, and Comments
# ---

# %% [markdown]
# ## 📌 Learning Objectives
# - Understand what Python is
# - Use the print() function
# - Write comments in code

# %% [markdown]
# ### 🧠 What is Python?
# Python is a beginner-friendly programming language used to build websites, automate tasks, analyze data, and more.

# %%
# Try using what you learned from: What is Python?

# %% [markdown]
# ### 🧠 The print() Function
# Use print() to display text or numbers to the screen.

# %%
print("Hello, world!")

# %%
print("Learning Python is fun!")

# %%
# Try using what you learned from: The print() Function

# %% [markdown]
# ### 🧠 Writing Comments
# Use # to add comments. Python ignores comments when running the code.

# %%
# This is a comment
print("This runs")

# %%
# Print your name
print("My name is Python")

# %%
# Try using what you learned from: Writing Comments

# %% [markdown]
# ## 🧪 Practice Tasks

# %% [markdown]
# **Task:** Print your name.

# %%
# Print your name.

# %% [markdown]
# **Task:** Print a motivational quote.

# %%
# Print a motivational quote.

# %% [markdown]
# **Task:** Add a comment above each print statement.

# %%
# Add a comment above each print statement.

# %% [markdown]
# ## 💡 Stretch Challenge

# %% [markdown]
# Write a short script that prints your name and two things you're excited to learn. Use at least two comments.

# %%
# Complete the stretch challenge here

# %% [markdown]
# ## 📘 Knowledge Check: Multiple Choice Questions
# **1. What does the print() function do?**
# - a) Takes input
# - b) Displays text
# - c) Adds numbers
# - d) Creates comments
# _Your Answer:_
#
# **2. Which symbol is used to write comments?**
# - a) //
# - b) **
# - c) #
# - d) <!-- -->
# _Your Answer:_
#
# **3. Which of these will print 'Hello'?**
# - a) print(Hello)
# - b) print['Hello']
# - c) print('Hello')
# - d) echo('Hello')
# _Your Answer:_
#
# **4. What is the output of print(5 + 3)?**
# - a) 53
# - b) 8
# - c) '5 + 3'
# - d) Error
# _Your Answer:_
#
# **5. Why are comments used in code?**
# - a) To speed up code
# - b) To explain code
# - c) To store data
# - d) To print text
# _Your Answer:_

# %% [markdown]
# ## ✅ Answer Key – Day 1
# 1. **b**
# 2. **c**
# 3. **c**
# 4. **b**
# 5. **b**
#
# ---

# %% [markdown]
# # 📅 Day 2: Variables and Assignment
# ---

# %% [markdown]
# ## 📌 Learning Objectives
# - Understand what variables are
# - Assign values to variables
# - Follow naming rules and best practices

# %% [markdown]
# ### 🧠 What is a Variable?
# A variable is like a labeled box that holds information. You can use it to store and reuse values in your code.

# %%
name = 'Alice'
print(name)

# %%
age = 30
print(age)

# %%
# Try it yourself: What is a Variable?

# %% [markdown]
# ### 🧠 Variable Naming Rules
# Variable names must start with a letter or underscore, can't use spaces, and are case-sensitive.

# %%
user_name = 'Bob'

# %%
_hidden_value = 42

# %%
# Try it yourself: Variable Naming Rules

# %% [markdown]
# ## 🧪 Practice Tasks

# %% [markdown]
# **Task:** Create a variable to store your favorite food.

# %%
# Create a variable to store your favorite food.

# %% [markdown]
# **Task:** Create a variable to store your height.

# %%
# Create a variable to store your height.

# %% [markdown]
# **Task:** Print both values with a label.

# %%
# Print both values with a label.

# %% [markdown]
# ## 💡 Stretch Challenge

# %% [markdown]
# Write a script that stores your name, age, and location in variables, then prints a short sentence using them.

# %%
# Complete your stretch challenge here

# %% [markdown]
# ## 📘 Knowledge Check: Multiple Choice Questions
# **1. What is a variable in Python?**
# - a) A loop
# - b) A data store
# - c) A comment
# - d) An error
# _Your Answer:_
#
# **2. Which of these is a valid variable name?**
# - a) 1number
# - b) user-age
# - c) _user
# - d) user name
# _Your Answer:_
#
# **3. What will this print?
#
# ```python
# x = 5
# y = 10
# print(x + y)
# ```**
# - a) 15
# - b) x + y
# - c) 510
# - d) Error
# _Your Answer:_
#
# **4. Which one is NOT a good variable name?**
# - a) score_1
# - b) UserName
# - c) my-score
# - d) total
# _Your Answer:_
#
# **5. What does Python do when you assign a variable?**
# - a) Deletes it
# - b) Stores the value
# - c) Prints it
# - d) Comments it
# _Your Answer:_

# %% [markdown]
# ## ✅ Answer Key – Day 2
# 1. **b**
# 2. **c**
# 3. **a**
# 4. **c**
# 5. **b**
#
# ---

# %% [markdown]
# # 📅 Day 3: Data Types and Type Checking
# ---

# %% [markdown]
# ## 📌 Learning Objectives
# - Identify basic data types
# - Check a variable’s type
# - Understand strings, integers, and floats

# %% [markdown]
# ### 🧠 What are Data Types?
# Every value in Python has a type, like a label. The most common types are strings, integers, and floats.

# %%
print(type('Hello'))  # string

# %%
print(type(42))       # integer

# %%
print(type(3.14))     # float

# %%
# Try it yourself: What are Data Types?

# %% [markdown]
# ### 🧠 Why Data Types Matter
# Different types allow Python to know how to handle and use values in different ways.

# %%
# Try it yourself: Why Data Types Matter

# %% [markdown]
# ## 🧪 Practice Tasks

# %% [markdown]
# **Task:** Create a string variable and check its type.

# %%
# Create a string variable and check its type.

# %% [markdown]
# **Task:** Create a float variable and check its type.

# %%
# Create a float variable and check its type.

# %% [markdown]
# **Task:** Create an integer variable and check its type.

# %%
# Create an integer variable and check its type.

# %% [markdown]
# ## 💡 Stretch Challenge

# %% [markdown]
# Write a program that creates three variables: one string, one integer, and one float. Print a sentence describing each one and its type.

# %%
# Complete your stretch challenge here

# %% [markdown]
# ## 📘 Knowledge Check: Multiple Choice Questions
# **1. What type is 'Hello'?**
# - a) int
# - b) float
# - c) str
# - d) bool
# _Your Answer:_
#
# **2. Which function checks a variable’s type?**
# - a) check()
# - b) verify()
# - c) typeof()
# - d) type()
# _Your Answer:_
#
# **3. What will this print?
#
# ```python
# a = 4.5
# print(type(a))
# ```**
# - a) <class 'float'>
# - b) float
# - c) decimal
# - d) number
# _Your Answer:_
#
# **4. Which is a float?**
# - a) 10
# - b) 10.0
# - c) '10'
# - d) 0
# _Your Answer:_
#
# **5. Why are data types important?**
# - a) They speed up code
# - b) They help organize files
# - c) They tell Python how to treat a value
# - d) They’re not important
# _Your Answer:_

# %% [markdown]
# ## ✅ Answer Key – Day 3
# 1. **c**
# 2. **d**
# 3. **a**
# 4. **b**
# 5. **c**
#
# ---
